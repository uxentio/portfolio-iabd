# %% [markdown]
# ## Breast_Cancer

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# upload files from your local machine  (info: https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html#examples-using-sklearn-datasets-load-breast-cancer)
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
X=data.data
y=data.target
print(X)
print(y)
print(X.shape)
print(y.shape)
